# %%
# Use a pipeline as a high-level helper
from transformers import pipeline
pipe = pipeline("text2text-generation", model="p208p2002/bart-squad-qg-hl")
# Out:
# All PyTorch model weights were used when initializing TFBartForConditionalGeneration.
#
# All the weights of TFBartForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBartForConditionalGeneration for predictions without further training.
# config.json: 100%|██████████| 1.45k/1.45k [00:00<00:00, 170kB/s]
# c:\Users\yaoji\AppData\Local\Programs\Python\Python39\lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\yaoji\.cache\huggingface\hub\models--dslim--bert-large-NER. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors: 100%|██████████| 1.33G/1.33G [01:21<00:00, 16.4MB/s]
# All PyTorch model weights were used when initializing TFBertForTokenClassification.
#
# All the weights of TFBertForTokenClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForTokenClassification for predictions without further training.
# tokenizer_config.json: 100%|██████████| 40.0/40.0 [00:00<00:00, 13.3kB/s]
# vocab.txt: 100%|██████████| 213k/213k [00:00<00:00, 25.1MB/s]
# special_tokens_map.json: 100%|██████████| 112/112 [00:00<00:00, 37.3kB/s]

# %%
input_text = "[HL] Python [HL] is an interpreted, [HL] high-level [HL], [HL] general-purpose [HL] programming language. Created by Guido van Rossum and first released in 1991, Python's design philosophy emphasizes code readability with its notable use of significant whitespace."

# Use the pipeline to generate text based on the input
output = pipe(input_text)

# Print the generated text
for o in output:
    print(o['generated_text'])
# Out:
# What type of programming language is Python?

# %% [markdown]
# Idea: load back all ngrams, clean stopwords and punkt from it

# %%
import pickle
with open("../all_ngrams.pkl", "rb") as input_file:
    all_ngrams = pickle.load(input_file)

# %%
import pandas as pd
df = pd.read_csv('../abstractive_summaries.csv')
sentences = df['Abstractive Summary'].tolist()
sentences = sentences[1:]

# %%
spacy.cli.download("en_core_web_lg")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import re
def extract_answers(text, nlp):
    doc = nlp(text)
    results = []

    # Function to determine if an n-gram is significant
    def is_significant(phrase):
        return any(token.pos_ in ['NOUN', 'PROPN', 'ADJ', 'VERB'] and not token.is_stop for token in phrase)

    for sent in doc.sents:
        tokens = [token for token in sent if not token.is_punct and not token.is_space]

        # Generate up to trigrams
        for n in range(1, 4):  # For unigrams, bigrams, and trigrams
            ngrams = [tokens[i:i+n] for i in range(len(tokens) - n + 1)]
            for ngram in ngrams:
                if is_significant(ngram):
                    ngram_text = " ".join(token.text for token in ngram)
                    pattern = re.escape(ngram_text)
                    replacement = "[HL]" + ngram_text + "[HL]"
                    highlighted_ngram = re.sub(pattern, replacement, text)
                    results.append((highlighted_ngram, ngram_text))

    return results

# %%
all_results = []
index = []
for idx, text in enumerate(sentences):
    results = extract_answers(text, nlp)
    all_results.extend(results)
    index.extend([idx] * len(results))

# %%
extracted_texts = [result[0] for result in all_results]
highlighted_texts = [result[1] for result in all_results]

new_df = pd.DataFrame({
    'index': index,
    'highlighted_sent': extracted_texts,
    'answer': highlighted_texts
})

# %% [markdown]
# The wacky part begins, here, we will input the highlighted parts into the pipe, and obtain an answer

# %%
from sklearn.model_selection import train_test_split


_, sample_df = train_test_split(new_df, test_size=0.1, stratify=new_df['index'], random_state=42)

sample_df
# Out:
#        index                                   highlighted_sent  \
# 20437    146  Antioxidants are compounds that can delay or i...
# 21426    153  All kidney transplant recipients at our center...
# 8668      61  Thrombocytosis, an uncommon side effect of all...
# 7774      55  Disruption risks in supply chains are low-freq...
# 21687    155  The first Covid-19 listed studies with pediatr...
# ...      ...                                                ...
# 465        3  In early 2020, the emerging respiratory virus ...
# 18483    132  Diedel, a protein secreted from peripheral tis...
# 5155      35  Animal models are crucial for the study of sev...
# 18712    134  Uganda hosts the largest number of refugees in...
# 7628      54  For the first time ever we discovered vitrifie...
#
#                               answer
# 20437               oxidative stress
# 21426                  28 recipients
# 8668                    of all trans
# 7774                    The existing
# 21687  develop neurological symptoms
# ...                              ...
# 465                             high
# 18483                   peroxide can
# 5155                The World Health
# 18712                access services
# 7628                          glassy
#
# [2169 rows x 3 columns]

# %%
new_df.to_csv('../extracted_HL.csv')

# %%
from tqdm.auto import tqdm
tqdm.pandas()
def apply_pipe(text):
    output = pipe(text)
    return output[0]['generated_text']

sample_df['question'] = sample_df['highlighted_sent'].progress_apply(apply_pipe)
sample_df
# Out:
#   0%|          | 0/2169 [00:00<?, ?it/s]c:\Users\yaoji\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\generation\tf_utils.py:838: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# 100%|██████████| 2169/2169 [1:47:38<00:00,  2.98s/it]
#        index                                   highlighted_sent  \
# 20437    146  Antioxidants are compounds that can delay or i...
# 21426    153  All kidney transplant recipients at our center...
# 8668      61  Thrombocytosis, an uncommon side effect of all...
# 7774      55  Disruption risks in supply chains are low-freq...
# 21687    155  The first Covid-19 listed studies with pediatr...
# ...      ...                                                ...
# 465        3  In early 2020, the emerging respiratory virus ...
# 18483    132  Diedel, a protein secreted from peripheral tis...
# 5155      35  Animal models are crucial for the study of sev...
# 18712    134  Uganda hosts the largest number of refugees in...
# 7628      54  For the first time ever we discovered vitrifie...
#
#                               answer  \
# 20437               oxidative stress
# 21426                  28 recipients
# 8668                    of all trans
# 7774                    The existing
# 21687  develop neurological symptoms
# ...                              ...
# 465                             high
# 18483                   peroxide can
# 5155                The World Health
# 18712                access services
# 7628                          glassy
#
#                                                 question
# 20437  What is a major role of antioxidants in cancer...
# 21426  How many kidney transplant recipients have und...
# 8668   What is one side effect of all-trans retinoic ...
# 7774   What type of interconnectivity could be a key ...
# 21687  What is uncertain about the long-term impact o...
# ...                                                  ...
# 465                 What type of efficacy does PPE have?
# 18483  What is the name of the enzyme that quenches h...
# 5155                    Who defines zoonotic disease as?
# 18712  What has the COVID-19 prevention and control s...
# 7628   What kind of residue was found in the brain ti...
#
# [2169 rows x 4 columns]

# %%
sample_df.to_csv('../question_answer_pair.csv', index=False)

# %%
sample_df = pd.read_csv('../question_answer_pair.csv')
sample_df
# Out:
#       index                                   highlighted_sent  \
# 0       146  Antioxidants are compounds that can delay or i...
# 1       153  All kidney transplant recipients at our center...
# 2        61  Thrombocytosis, an uncommon side effect of all...
# 3        55  Disruption risks in supply chains are low-freq...
# 4       155  The first Covid-19 listed studies with pediatr...
# ...     ...                                                ...
# 2164      3  In early 2020, the emerging respiratory virus ...
# 2165    132  Diedel, a protein secreted from peripheral tis...
# 2166     35  Animal models are crucial for the study of sev...
# 2167    134  Uganda hosts the largest number of refugees in...
# 2168     54  For the first time ever we discovered vitrifie...
#
#                              answer  \
# 0                  oxidative stress
# 1                     28 recipients
# 2                      of all trans
# 3                      The existing
# 4     develop neurological symptoms
# ...                             ...
# 2164                           high
# 2165                   peroxide can
# 2166               The World Health
# 2167                access services
# 2168                         glassy
#
#                                                question
# 0     What is a major role of antioxidants in cancer...
# 1     How many kidney transplant recipients have und...
# 2     What is one side effect of all-trans retinoic ...
# 3     What type of interconnectivity could be a key ...
# 4     What is uncertain about the long-term impact o...
# ...                                                 ...
# 2164               What type of efficacy does PPE have?
# 2165  What is the name of the enzyme that quenches h...
# 2166                   Who defines zoonotic disease as?
# 2167  What has the COVID-19 prevention and control s...
# 2168  What kind of residue was found in the brain ti...
#
# [2169 rows x 4 columns]
